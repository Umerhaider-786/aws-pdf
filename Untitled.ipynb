# %%
# !pip install streamlit scikit-learn pandas numpy
# Out:
# Requirement already satisfied: streamlit in d:\softwares\anaconda\lib\site-packages (1.45.1)
# Requirement already satisfied: scikit-learn in d:\softwares\anaconda\lib\site-packages (1.6.1)
# Requirement already satisfied: pandas in d:\softwares\anaconda\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in d:\softwares\anaconda\lib\site-packages (2.1.3)
# Requirement already satisfied: altair<6,>=4.0 in d:\softwares\anaconda\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in d:\softwares\anaconda\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in d:\softwares\anaconda\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in d:\softwares\anaconda\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: packaging<25,>=20 in d:\softwares\anaconda\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in d:\softwares\anaconda\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in d:\softwares\anaconda\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in d:\softwares\anaconda\lib\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in d:\softwares\anaconda\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in d:\softwares\anaconda\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in d:\softwares\anaconda\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in d:\softwares\anaconda\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in d:\softwares\anaconda\lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in d:\softwares\anaconda\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in d:\softwares\anaconda\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\softwares\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\softwares\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\softwares\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: jinja2 in d:\softwares\anaconda\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in d:\softwares\anaconda\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in d:\softwares\anaconda\lib\site-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: colorama in d:\softwares\anaconda\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\softwares\anaconda\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in d:\softwares\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\softwares\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\softwares\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\softwares\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\softwares\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: scipy>=1.6.0 in d:\softwares\anaconda\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\softwares\anaconda\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\softwares\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\softwares\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\softwares\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\softwares\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\softwares\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in d:\softwares\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\softwares\anaconda\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

columns = ["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age","Outcome"]

df = pd.read_csv(url, names=columns)

df.to_csv("diabetes.csv", index=False)

print("Real dataset loaded")
# Out:
# Real dataset loaded

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import pickle

df = pd.read_csv("diabetes.csv")

X = df.drop("Outcome", axis=1)
y = df["Outcome"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestClassifier()
model.fit(X_train, y_train)

with open("diabetes_model.pkl", "wb") as f:
    pickle.dump(model, f)

print("Model trained")
# Out:
# Model trained
